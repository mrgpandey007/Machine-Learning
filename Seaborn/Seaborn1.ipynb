# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.size
# Out:
# 1708

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
sns.displot(df['total_bill'],bins=25) #histogram graph here bins are number of blue tower boxes

# %%
sns.histplot(df['total_bill'],bins=25, kde=True)   # histplot==displot
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins=25)

plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=25)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # Jointplot()

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %% [markdown]
# # pairsplot()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='sex',palette='rainbow')

# %% [markdown]
# # rugplot()

# %%
sns.rugplot(df)
