# %% [markdown]
# # loading the libraries in the file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
import plotly.express as px
import plotly.graph_objs as go

# %% [markdown]
# # Loading warning files to ignore the warnings in this file

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\Machine Learning\IPL Data Explorer Small Project\IPL.csv")
df
# Out:
#                             TEAM               PLAYER           TYPE  \
# 0          Kolkata Knight Riders          Pat Cummins    All-Rounder
# 1                Kings XI Punjab        Glenn Maxwell    All-Rounder
# 2    Royal Challengers Bangalore   Christopher Morris    All-Rounder
# 3                Kings XI Punjab     Sheldon Cottrell         Bowler
# 4                 Mumbai Indians  Nathan Coulter-Nile         Bowler
# 5                 Delhi Capitals      Shimron Hetmyer        Batsman
# 6            Chennai Super Kings        Piyush Chawla         Bowler
# 7            Chennai Super Kings           Sam Curran    All-Rounder
# 8               Rajasthan Royals       Jaydev Unadkat         Bowler
# 9                Kings XI Punjab  Varun Chakaravarthy    All-Rounder
# 10               Kings XI Punjab           Sam Curran    All-Rounder
# 11                Delhi Capitals         Colin Ingram        Batsman
# 12         Kolkata Knight Riders    Carlos Brathwaite    All-Rounder
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   TEAM                            56 non-null     object
#  1   PLAYER                          56 non-null     object
#  2   TYPE                            56 non-null     object
#  3   PRICE(In crore Indian Rupees)   56 non-null     float64
#  4   YEAR                            56 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
df.shape
# Out:
# (56, 5)

# %%
df.shape[0]
# Out:
# 56

# %%
df.isnull().sum() #counts the null values in the data frame
# Out:
# TEAM                              0
# PLAYER                            0
# TYPE                              0
# PRICE(In crore Indian Rupees)     0
# YEAR                              0
# dtype: int64

# %%
p=df['PLAYER'].value_counts()
sns.barplot(y=p.index,x=p.values)
plt.title('PLAYER:')
# Out:
# Text(0.5, 1.0, 'PLAYER:')

# %%
df.head()
# Out:
#                            TEAM               PLAYER         TYPE  \
# 0         Kolkata Knight Riders          Pat Cummins  All-Rounder
# 1               Kings XI Punjab        Glenn Maxwell  All-Rounder
# 2   Royal Challengers Bangalore   Christopher Morris  All-Rounder
# 3               Kings XI Punjab     Sheldon Cottrell       Bowler
# 4                Mumbai Indians  Nathan Coulter-Nile       Bowler
#
#    PRICE(In crore Indian Rupees)   YEAR
# 0                           15.50  2020
# 1                           10.75  2020
# 2                           10.00  2020
# 3                            8.50  2020
# 4                            8.00  2020

# %%
sns.countplot(x=df['YEAR'])
plt.title('Match by year')
# Out:
# Text(0.5, 1.0, 'Match by year')

# %%
xq=df['PLAYER'].value_counts().head(10)
sns.barplot(x=xq.values,y=xq.index,palette='dark')
plt.title("Top 10 PLayer")
# Out:
# Text(0.5, 1.0, 'Top 10 PLayer')

# %%
h=df.groupby('TYPE')['YEAR'].count()
h
# Out:
# TYPE
# All-Rounder      23
# Batsman          11
# Bowler           20
# Wicket Keeper     2
# Name: YEAR, dtype: int64

# %%
h.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>
